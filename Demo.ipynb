# %% [markdown]
# #                                                      Demo

# %%
from IPython.display import Image, clear_output

# %% [markdown]
# #### Run Net

# %%
# !python3 detect.py --data data_voc/2012_train.data --cfg cfg/yolov3-voc-anchors_plus_focal_loss.cfg --weights wts_anchor_plus_focal_loss.pt --source data/samples
# Out:
# Namespace(cfg='cfg/yolov3-voc-anchors_plus_focal_loss.cfg', conf_thres=0.3, data='data_voc/2012_train.data', device='', fourcc='mp4v', half=False, img_size=416, nms_thres=0.5, output='output', source='data/samples', view_img=False, weights='wts_anchor_plus_focal_loss.pt')
# Using CUDA device0 _CudaDeviceProperties(name='GeForce GTX 1080 Ti', total_memory=11178MB)
#
# image 1/5 data/samples/000057.jpg: 320x416 1 birds, Done. (0.262s)
# image 2/5 data/samples/000341.jpg: 288x416 1 buss, 4 cars, 2 persons, Done. (0.029s)
# image 3/5 data/samples/000393.jpg: 288x416 1 horses, 1 persons, Done. (0.020s)
# image 4/5 data/samples/bus.jpg: 416x320 1 buss, 2 persons, Done. (0.023s)
# image 5/5 data/samples/zidane.jpg: 256x416 2 persons, Done. (0.022s)
# Results saved to /datasets/home/home-02/69/069/snayak/ECE285_FinalProject/ECE-285-Project-YOLOv3/output
# Done. (0.470s)

# %% [markdown]
# #### Example 1

# %%
Image(filename='output/000393.jpg', width=600)

# %% [markdown]
# #### Example 2

# %%
Image(filename='output/000341.jpg', width=600)
